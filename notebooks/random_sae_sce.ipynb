# %%
import pandas as pd
import numpy as np
from contextlib import chdir
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import binomtest
import math
import sys
import gseapy as gp

# %%
with chdir('..'):
    CCDS_split = pd.read_csv('ref_data/modified/CCDS_split.csv')

# %%
SAEs = CCDS_split[CCDS_split['type'] == 'SAE']
SCEs = CCDS_split[CCDS_split['type'] == 'SCE']

# %%
with chdir('..'):
    CCDS_split = pd.read_csv('ref_data/modified/CCDS.csv')
